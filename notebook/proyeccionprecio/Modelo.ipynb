# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import plot_tree
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_log_error, mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import cross_val_score

from sklearn.model_selection import cross_validate
from sklearn.metrics import make_scorer
from sklearn.pipeline import Pipeline

# %%
df = pd.read_csv("../../data/precio/dfnorm.csv", index_col = 0)
df.head()
# Out:
#        edad  Valoración actual  Progresión   precio    Ataque    Regate  \
# 0  1.826700           1.323359   -0.889897  3300000  0.002999 -2.067653
# 1  0.369777           1.323359    1.005344  3800000  0.457513  1.649663
# 2 -1.087145           1.323359    0.373597  3600000  0.457513  0.748495
# 3  1.098239           1.323359   -0.258150  3500000 -0.724223  0.185265
# 4  1.826700           1.323359   -0.258150  3600000  0.366611  0.635849
#
#    Aceleración  Potencia tiro  Agresividad   Defensa
# 0    -1.428951      -2.402604     0.839337  1.321880
# 1     1.313775       0.529640    -1.626190 -1.094921
# 2     0.690428       1.018347     0.441671 -0.231778
# 3    -0.306927       1.507054     0.759804 -0.807207
# 4    -0.057588       1.311571     1.555135 -1.440179

# %%
df = df.select_dtypes(include=np.number)
df.head()
# Out:
#        edad  Valoración actual  Progresión   precio    Ataque    Regate  \
# 0  1.826700           1.323359   -0.889897  3300000  0.002999 -2.067653
# 1  0.369777           1.323359    1.005344  3800000  0.457513  1.649663
# 2 -1.087145           1.323359    0.373597  3600000  0.457513  0.748495
# 3  1.098239           1.323359   -0.258150  3500000 -0.724223  0.185265
# 4  1.826700           1.323359   -0.258150  3600000  0.366611  0.635849
#
#    Aceleración  Potencia tiro  Agresividad   Defensa
# 0    -1.428951      -2.402604     0.839337  1.321880
# 1     1.313775       0.529640    -1.626190 -1.094921
# 2     0.690428       1.018347     0.441671 -0.231778
# 3    -0.306927       1.507054     0.759804 -0.807207
# 4    -0.057588       1.311571     1.555135 -1.440179

# %%
df.describe().T.head()
# Out:
#                    count          mean            std            min  \
# edad               394.0 -1.154181e-15       1.001271      -1.815607
# Valoración actual  394.0  5.770905e-16       1.001271      -2.842740
# Progresión         394.0 -3.040997e-15       1.001271      -0.889897
# precio             394.0  2.177030e+06  926051.938525  525000.000000
# Ataque             394.0  2.524771e-16       1.001271      -2.724085
#
#                             25%           50%           75%           max
# edad              -1.087145e+00 -3.586841e-01  3.697774e-01  1.826700e+00
# Valoración actual -5.994563e-01  4.148205e-02  1.002890e+00  1.323359e+00
# Progresión        -8.898974e-01 -2.581504e-01  3.735966e-01  3.532332e+00
# precio             1.500000e+06  2.050000e+06  3.100000e+06  4.099999e+06
# Ataque            -6.333205e-01  1.848050e-01  7.302219e-01  2.366473e+00

# %%
y = df["precio"]
X = df.drop(columns=["precio"])

# %%
pipe = Pipeline(steps=[('estimator', LinearRegression())])

# %%
params_grid = [{
                'estimator':[LinearRegression()],
                },
                {
                'estimator': [DecisionTreeRegressor()],
                'estimator__max_depth': [4, 5, 6, 7],
                'estimator__max_features': ["sqrt", "log2"],
                'estimator__min_samples_split': [10, 50, 100], 
                'estimator__min_samples_leaf':[1,2,3],
                },
                {'estimator':[RandomForestRegressor()],
                 'estimator__n_estimators':[50,100,200,300],
                 'estimator__max_depth':[4, 5, 6, 7, 9], 
                 'estimator__min_samples_split':[2,3,4], 
                 'estimator__min_samples_leaf':[1,2,3],
                },
                {'estimator':[KNeighborsRegressor()],
                 'estimator__n_neighbors':[3,5,6,7, 8, 9, 10],
                }

              ]

# %%
grid = GridSearchCV(pipe, params_grid, n_jobs= -1, verbose = 3)

# %%
# %%time
res = grid.fit(X, y)
# Out:
# Fitting 5 folds for each of 260 candidates, totalling 1300 fits
# Wall time: 2min 11s

# %%
best_model = grid.best_params_
best_model
# Out:
# {'estimator': RandomForestRegressor(max_depth=9, min_samples_split=3),
#  'estimator__max_depth': 9,
#  'estimator__min_samples_leaf': 1,
#  'estimator__min_samples_split': 3,
#  'estimator__n_estimators': 100}

# %%
results = pd.DataFrame(grid.cv_results_).head()
results.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.006198      0.000747         0.003597        0.000489
# 1       0.079183      0.035220         0.012489        0.006245
# 2       0.003125      0.006250         0.000000        0.000000
# 3       0.009375      0.007655         0.006250        0.007654
# 4       0.003125      0.006250         0.006250        0.007654
#
#            param_estimator param_estimator__max_depth  \
# 0       LinearRegression()                        NaN
# 1  DecisionTreeRegressor()                          4
# 2  DecisionTreeRegressor()                          4
# 3  DecisionTreeRegressor()                          4
# 4  DecisionTreeRegressor()                          4
#
#   param_estimator__max_features param_estimator__min_samples_leaf  \
# 0                           NaN                               NaN
# 1                          sqrt                                 1
# 2                          sqrt                                 1
# 3                          sqrt                                 1
# 4                          sqrt                                 2
#
#   param_estimator__min_samples_split param_estimator__n_estimators  \
# 0                                NaN                           NaN
# 1                                 10                           NaN
# 2                                 50                           NaN
# 3                                100                           NaN
# 4                                 10                           NaN
#
#   param_estimator__n_neighbors  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
#                                               params  split0_test_score  \
# 0                  {'estimator': LinearRegression()}          -0.836455
# 1  {'estimator': DecisionTreeRegressor(), 'estima...          -8.401827
# 2  {'estimator': DecisionTreeRegressor(), 'estima...          -9.792303
# 3  {'estimator': DecisionTreeRegressor(), 'estima...         -22.866329
# 4  {'estimator': DecisionTreeRegressor(), 'estima...         -24.910127
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.801489           0.564084          -0.156332          -5.606011
# 1          -3.223535          -3.135650          -3.957871          -7.007534
# 2          -2.397281          -2.394925          -5.080203         -21.996500
# 3          -2.094540          -3.722396          -3.939307         -10.778298
# 4           0.228137          -4.266424          -3.989265         -10.508782
#
#    mean_test_score  std_test_score  rank_test_score
# 0        -1.046645        2.350945              181
# 1        -5.145283        2.154750              210
# 2        -8.332243        7.347040              242
# 3        -8.680174        7.695129              247
# 4        -8.689292        8.804528              248

# %%
results = cross_validate(RandomForestRegressor(max_depth=9, min_samples_split=3), 
               X=X, y=y, scoring='neg_root_mean_squared_error', cv=10, verbose = 3,  n_jobs= -1)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    2.0s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    2.6s finished

# %%
rmse_ = abs(results["test_score"].mean())
rmse_
# Out:
# 105138.69406916939
